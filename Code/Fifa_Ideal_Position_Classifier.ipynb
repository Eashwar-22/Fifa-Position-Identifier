# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 30)

# %%
df_orig = pd.read_csv('../Data/players.csv')

# %%
df_orig.head()
# Out:
#    int_player_id                      str_player_name str_positions  \
# 0              1       Lionel Andrés Messi Cuccittini    RW, ST, CF
# 1              2  Cristiano Ronaldo dos Santos Aveiro        ST, LW
# 2              3                            Jan Oblak            GK
# 3              4                      Kevin De Bruyne       CAM, CM
# 4              5        Neymar da Silva Santos Júnior       LW, CAM
#
#   dt_date_of_birth  int_height  int_weight  int_overall_rating  \
# 0       1987-06-24         170          72                  93
# 1       1985-02-05         187          83                  92
# 2       1993-01-07         188          87                  91
# 3       1991-06-28         181          70                  91
# 4       1992-02-05         175          68                  91
#
#    int_potential_rating str_best_position  int_best_overall_rating  int_value  \
# 0                    93                RW                       93  103500000
# 1                    92                ST                       92   63000000
# 2                    93                GK                       91  120000000
# 3                    91               CAM                       91  129000000
# 4                    91                LW                       91  132000000
#
#    int_wage  int_team_id str_nationality  int_crossing  int_finishing  \
# 0    560000          5.0       Argentina            85             95
# 1    220000          6.0        Portugal            84             95
# 2    125000          8.0        Slovenia            13             11
# 3    370000          2.0         Belgium            94             82
# 4    270000          7.0          Brazil            85             87
#
#    int_heading_accuracy  int_short_passing  int_volleys  \
# 0                    70                 91           88
# 1                    90                 82           86
# 2                    15                 43           13
# 3                    55                 94           82
# 4                    62                 87           87
#
#    int_defensive_awareness  int_standing_tackle  int_sliding_tackle  \
# 0                       32                   35                  24
# 1                       28                   32                  24
# 2                       27                   12                  18
# 3                       68                   65                  53
# 4                       35                   30                  29
#
#    int_diving  int_handling  int_kicking  int_gk_positioning  int_reflexes  \
# 0           6            11           15                  14             8
# 1           7            11           15                  14            11
# 2          87            92           78                  90            90
# 3          15            13            5                  10            13
# 4           9             9           15                  15            11
#
#    int_aggression  int_interceptions  int_positioning  int_vision  \
# 0              44                 40               93          95
# 1              63                 29               95          82
# 2              34                 19               11          65
# 3              76                 66               88          94
# 4              51                 36               87          90
#
#    int_penalties  int_composure  int_acceleration  int_sprint_speed  \
# 0             75             96                91                80
# 1             84             95                87                91
# 2             11             68                43                60
# 3             84             91                77                76
# 4             92             93                94                89
#
#    int_agility  int_reactions  int_balance  int_shot_power  int_jumping  \
# 0           91             94           95              86           68
# 1           87             95           71              94           95
# 2           67             88           49              59           78
# 3           78             91           76              91           63
# 4           96             91           83              80           62
#
#    int_stamina  int_strength  int_long_shots str_preferred_foot  \
# 0           72            69              94               Left
# 1           84            78              93              Right
# 2           41            78              12              Right
# 3           89            74              91              Right
# 4           81            50              84              Right
#
#    int_weak_foot  int_skill_moves  int_international_reputations  \
# 0              4                4                              5
# 1              4                5                              5
# 2              3                1                              3
# 3              5                4                              4
# 4              5                5                              5
#
#     str_work_rate str_body_type  int_dribbling  int_curve  int_fk_accuracy  \
# 0     Medium/ Low        Unique             96         93               94
# 1       High/ Low        Unique             88         81               76
# 2  Medium/ Medium        Unique             12         13               14
# 3      High/ High        Unique             88         85               83
# 4    High/ Medium        Unique             95         88               89
#
#    int_long_passing  int_ball_control  \
# 0                91                96
# 1                77                92
# 2                40                30
# 3                93                92
# 4                81                95
#
#                                str_player_speciality  \
# 0  ['Dribbler', 'Distance Shooter', 'FK Specialis...
# 1  ['Aerial Threat', 'Dribbler', 'Distance Shoote...
# 2                                                NaN
# 3  ['Dribbler', 'Playmaker\xa0', 'Engine', 'Dista...
# 4  ['Speedster', 'Dribbler', 'Playmaker\xa0', 'FK...
#
#                                            str_trait
# 0  ['Finesse Shot', 'Long Shot Taker (AI)', 'Spee...
# 1  ['Power Free-Kick', 'Flair', 'Long Shot Taker ...
# 2             ['GK Long Throw', 'Comes For Crosses']
# 3  ['Injury Prone', 'Leadership', 'Early Crosser'...
# 4  ['Injury Prone', 'Flair', 'Speed Dribbler (AI)...

# %%
df_orig.columns=[i.replace('int_','').replace('str_','').replace('dt_','') for i in df_orig.columns]
df_orig.columns
# Out:
# Index(['player_id', 'player_name', 'positions', 'date_of_birth', 'height',
#        'weight', 'overall_rating', 'potential_rating', 'best_position',
#        'best_overall_rating', 'value', 'wage', 'team_id', 'nationality',
#        'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'defensive_awareness', 'standing_tackle', 'sliding_tackle', 'diving',
#        'handling', 'kicking', 'gk_positioning', 'reflexes', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'composure',
#        'acceleration', 'sprspeed', 'agility', 'reactions', 'balance',
#        'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputations', 'work_rate', 'body_type', 'dribbling',
#        'curve', 'fk_accuracy', 'long_passing', 'ball_control',
#        'player_speciality', 'trait'],
#       dtype='object')

# %% [markdown]
# ### Pre-processing to be done on columns
# -  Drop unnecessary columns (such as date_of_birth,potential_rating,best_overall_rating,etc.)
# - 'work-rate' : remove spaces in string<br>
# - 'positions' : (Target variable)
# > remove spaces <br>
# > convert the comma seperated string into list <br>
# > split them into columns <br>
# -  Add them all to a Custom Transformer and pass it to preprocessing pipeline

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class CustomTarget(BaseEstimator, TransformerMixin):
    def __init__(self,columns_to_drop=[]):
        self.drop_col=columns_to_drop

    def fit(self, X, y=None):
        return self

    def transform(self, X,y):
        X['work_rate']=X['work_rate'].apply(lambda x : x.replace(' ',''))
        
        self.all_positions = list(X['best_position'].unique())
        target=pd.DataFrame(y.copy())
        target['positions']=target['positions'].apply(lambda x : x.replace(' ','').split(','))
        for i in self.all_positions:
            target[i]=target['positions'].apply(lambda x: int(i in x))
        target.drop(columns='positions',inplace=True)
        target = np.array(target)
        
        if len(self.drop_col)!=0:
            X.drop(columns=self.drop_col,inplace=True)
        
            
        return X,target

# %%
X.shape,y.shape
# Out:
# ((19002, 55), (19002,))

# %%
columns_to_drop = ['player_id', 'player_name','date_of_birth','overall_rating', 
                   'potential_rating','best_position','value', 'wage', 'team_id',
                   'nationality','weak_foot', 'skill_moves','international_reputations',
                   'body_type','player_speciality', 'trait']

custom_transformer = CustomTarget(columns_to_drop=columns_to_drop)
pipeline = Pipeline([('custom_transformer',custom_transformer)])

# %%
pipeline.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-f36b656bff1e> in <module>
# ----> 1 pipeline.fit_transform(X)
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     385             fit_params_last_step = fit_params_steps[self.steps[-1][0]]
#     386             if hasattr(last_step, 'fit_transform'):
# --> 387                 return last_step.fit_transform(Xt, y, **fit_params_last_step)
#     388             else:
#     389                 return last_step.fit(Xt, y,
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# TypeError: transform() missing 1 required positional argument: 'y'

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

# %%
# Custom transformer
def transform_work_rate(df):
    df['work_rate']=df['work_rate'].apply(lambda x : x.replace(' ',''))
    return df

def transform_positions(df):
    all_positions = list(df['best_position'].unique())
    df['positions']=df['positions'].apply(lambda x : x.replace(' ','').split(','))
    for i in all_positions:
        df[i]=df['positions'].apply(lambda x: int(i in x))
    return df

work_rate_transformer = FunctionTransformer(transform_work_rate)
positions_transformer = FunctionTransformer(transform_positions)


# Drop transformer
drop_col=['player_id', 'player_name','date_of_birth','overall_rating', 'potential_rating','best_position',
          'value', 'wage', 'team_id', 'nationality','weak_foot', 'skill_moves','international_reputations',
          'body_type','player_speciality', 'trait']

drop_transformer = ColumnTransformer(transformers = [('drop_columns','drop',drop_col)],
                                     remainder='passthrough')

# %%
pipeline = Pipeline([
                       ('work_rate',work_rate_transformer),
                       ('positions',positions_transformer),
                       ('drop_column',drop_transformer)
])

# %%
df = df_orig.copy()
df.head()
# Out:
#    player_id                          player_name   positions date_of_birth  \
# 0          1       Lionel Andrés Messi Cuccittini  RW, ST, CF    1987-06-24
# 1          2  Cristiano Ronaldo dos Santos Aveiro      ST, LW    1985-02-05
# 2          3                            Jan Oblak          GK    1993-01-07
# 3          4                      Kevin De Bruyne     CAM, CM    1991-06-28
# 4          5        Neymar da Silva Santos Júnior     LW, CAM    1992-02-05
#
#    height  weight  overall_rating  potential_rating best_position  \
# 0     170      72              93                93            RW
# 1     187      83              92                92            ST
# 2     188      87              91                93            GK
# 3     181      70              91                91           CAM
# 4     175      68              91                91            LW
#
#    best_overall_rating      value    wage  team_id nationality  crossing  \
# 0                   93  103500000  560000      5.0   Argentina        85
# 1                   92   63000000  220000      6.0    Portugal        84
# 2                   91  120000000  125000      8.0    Slovenia        13
# 3                   91  129000000  370000      2.0     Belgium        94
# 4                   91  132000000  270000      7.0      Brazil        85
#
#    finishing  heading_accuracy  short_passing  volleys  defensive_awareness  \
# 0         95                70             91       88                   32
# 1         95                90             82       86                   28
# 2         11                15             43       13                   27
# 3         82                55             94       82                   68
# 4         87                62             87       87                   35
#
#    standing_tackle  sliding_tackle  diving  handling  kicking  gk_positioning  \
# 0               35              24       6        11       15              14
# 1               32              24       7        11       15              14
# 2               12              18      87        92       78              90
# 3               65              53      15        13        5              10
# 4               30              29       9         9       15              15
#
#    reflexes  aggression  interceptions  positioning  vision  penalties  \
# 0         8          44             40           93      95         75
# 1        11          63             29           95      82         84
# 2        90          34             19           11      65         11
# 3        13          76             66           88      94         84
# 4        11          51             36           87      90         92
#
#    composure  acceleration  sprspeed  agility  reactions  balance  shot_power  \
# 0         96            91        80       91         94       95          86
# 1         95            87        91       87         95       71          94
# 2         68            43        60       67         88       49          59
# 3         91            77        76       78         91       76          91
# 4         93            94        89       96         91       83          80
#
#    jumping  stamina  strength  long_shots preferred_foot  weak_foot  \
# 0       68       72        69          94           Left          4
# 1       95       84        78          93          Right          4
# 2       78       41        78          12          Right          3
# 3       63       89        74          91          Right          5
# 4       62       81        50          84          Right          5
#
#    skill_moves  international_reputations       work_rate body_type  \
# 0            4                          5     Medium/ Low    Unique
# 1            5                          5       High/ Low    Unique
# 2            1                          3  Medium/ Medium    Unique
# 3            4                          4      High/ High    Unique
# 4            5                          5    High/ Medium    Unique
#
#    dribbling  curve  fk_accuracy  long_passing  ball_control  \
# 0         96     93           94            91            96
# 1         88     81           76            77            92
# 2         12     13           14            40            30
# 3         88     85           83            93            92
# 4         95     88           89            81            95
#
#                                    player_speciality  \
# 0  ['Dribbler', 'Distance Shooter', 'FK Specialis...
# 1  ['Aerial Threat', 'Dribbler', 'Distance Shoote...
# 2                                                NaN
# 3  ['Dribbler', 'Playmaker\xa0', 'Engine', 'Dista...
# 4  ['Speedster', 'Dribbler', 'Playmaker\xa0', 'FK...
#
#                                                trait
# 0  ['Finesse Shot', 'Long Shot Taker (AI)', 'Spee...
# 1  ['Power Free-Kick', 'Flair', 'Long Shot Taker ...
# 2             ['GK Long Throw', 'Comes For Crosses']
# 3  ['Injury Prone', 'Leadership', 'Early Crosser'...
# 4  ['Injury Prone', 'Flair', 'Speed Dribbler (AI)...

# %%
df = pipeline.fit_transform(df)

# %%
df_orig2 = df_orig.copy()
df_orig2['work_rate']=df_orig2['work_rate'].apply(lambda x : x.replace(' ',''))
df_orig2['positions']=df_orig2['positions'].apply(lambda x : x.replace(' ','').split(','))

df=df_orig2.copy()
df=df[['height',
       'weight', 'overall_rating', 
       'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
       'defensive_awareness', 'standing_tackle', 'sliding_tackle', 'diving',
       'handling', 'kicking', 'gk_positioning', 'reflexes', 'aggression',
       'interceptions', 'positioning', 'vision', 'penalties', 'composure',
       'acceleration', 'sprspeed', 'agility', 'reactions', 'balance',
       'shot_power', 'jumping', 'stamina', 'strength','long_shots',
       'work_rate', 'dribbling',
       'curve', 'fk_accuracy', 'long_passing', 'ball_control',
       'positions']]
df.columns
# Out:
# Index(['height', 'weight', 'overall_rating', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'defensive_awareness',
#        'standing_tackle', 'sliding_tackle', 'diving', 'handling', 'kicking',
#        'gk_positioning', 'reflexes', 'aggression', 'interceptions',
#        'positioning', 'vision', 'penalties', 'composure', 'acceleration',
#        'sprspeed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping',
#        'stamina', 'strength', 'long_shots', 'work_rate', 'dribbling', 'curve',
#        'fk_accuracy', 'long_passing', 'ball_control', 'positions'],
#       dtype='object')

# %% [markdown]
# > **EDA**

# %% [markdown]
# ### Multilabel Classification

# %%
# Pipeline
from sklearn.pipeline import Pipeline

# preprocessor
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# estimator
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df.head()

# %%
# Numerical Features
num_col = numerical_features.copy()

num_steps = [
             ('impute',SimpleImputer(strategy='mean')),
             ('scaler', StandardScaler()),
            ]

num_pipeline = Pipeline(num_steps)

# %%
# Categorical features
cat_col = ['work_rate','']

cat_steps = [
             ('impute',SimpleImputer(strategy='constant')),
             ('encoder',OneHotEncoder())
            ]
cat_pipeline = Pipeline(cat_steps)

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
X=df[numerical_features].copy()
temp=df['work_rate'].copy()
t=pd.get_dummies(temp,drop_first=True)
X=X.join(t)

y_orig=df['best_position'].copy()
mapping = {i:j for i,j in zip(y_orig.unique(),range(y_orig.nunique()))}
reverse_mapping={value:key for key, value in mapping.items()}
y=y_orig.map(mapping).copy()
y=np.array(y).reshape(-1,1)
# y=pd.get_dummies(y_orig,drop_first=True)

# %%
y

# %%
X.shape,y.shape

# %%
X.head()

# %%
numerical_features

# %%
dtc = DecisionTreeClassifier(max_depth = 2).fit(X, y)

dtc.fit(X,y)

# %%
y_pred = dtc.predict(X)

# %%
cm = confusion_matrix(y, y_pred)

# %%
y_pred

# %%
cm

# %%
y_pred_name = pd.Series(y_pred).map(reverse_mapping)

# %%
y_orig,y_pred_name

# %%
df_orig = pd.read_csv('../Data/players.csv')
df_orig.columns=[i.replace('int_','').replace('str_','').replace('dt_','') for i in df_orig.columns]

temp = df_orig[['height','weight', 'overall_rating', 
       'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
       'defensive_awareness', 'standing_tackle', 'sliding_tackle', 'diving',
       'handling', 'kicking', 'gk_positioning', 'reflexes', 'aggression',
       'interceptions', 'positioning', 'vision', 'penalties', 'composure',
       'acceleration', 'sprspeed', 'agility', 'reactions', 'balance',
       'shot_power', 'jumping', 'stamina', 'strength','long_shots',
       'work_rate', 'dribbling',
       'curve', 'fk_accuracy', 'long_passing', 'ball_control',
       'positions']].copy()
temp['positions'] = temp['positions'].apply(lambda x: x.replace(' ',''))
temp['positions'] = temp['positions'].apply(lambda x: x.split(','))
temp['work_rate'] = temp['work_rate'].apply(lambda x: x.replace(' ',''))

all_positions = list(df_orig['best_position'].unique())

# %%
temp

# %%
all_positions,len(all_positions)

# %%
temp['work_rate'].unique()

# %%
for i in all_positions:
    temp[i]=temp['positions'].apply(lambda x: int(i in x))

# %%
temp1=temp[[i for i in temp.columns if i not in ['positions','work_rate']]].copy()

# %%
X=temp1[['height', 'weight', 'overall_rating', 'crossing', 'finishing',
       'heading_accuracy', 'short_passing', 'volleys', 'defensive_awareness',
       'standing_tackle', 'sliding_tackle', 'diving', 'handling', 'kicking',
       'gk_positioning', 'reflexes', 'aggression', 'interceptions',
       'positioning', 'vision', 'penalties', 'composure', 'acceleration',
       'sprspeed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping',
       'stamina', 'strength', 'long_shots',  'dribbling', 'curve',
       'fk_accuracy', 'long_passing', 'ball_control' ]].copy()
y=temp1[['RW', 'ST', 'GK', 'CAM',
       'LW', 'CB', 'CDM', 'CF', 'LM', 'CM', 'RB', 'LB', 'RM', 'LWB', 'RWB']].copy()

# %%
from skmultilearn.problem_transform import ClassifierChain
from sklearn.linear_model import LogisticRegression

# %%
inp=np.array(X.iloc[0,:])
inp

# %%
classifier = ClassifierChain(LogisticRegression(C=1))
classifier.fit(X, y)
predictions = classifier.predict(X)

# %%
np.array(predictions.todense())

# %%
np.array(y)

# %%
np.array(y.iloc[0,:])

# %%
import pandas_profiling

# %%
df_orig
# Out:
#        player_id                          player_name   positions  \
# 0              1       Lionel Andrés Messi Cuccittini  RW, ST, CF
# 1              2  Cristiano Ronaldo dos Santos Aveiro      ST, LW
# 2              3                            Jan Oblak          GK
# 3              4                      Kevin De Bruyne     CAM, CM
# 4              5        Neymar da Silva Santos Júnior     LW, CAM
# ...          ...                                  ...         ...
# 18997      18998                                  张梦炫          CB
# 18998      18999                        Vani Da Silva          ST
# 18999      19000                                   夏奥          CB
# 19000      19001                            Ben Hough          CM
# 19001      19002          Mateo Nicolás Flores Cuevas         CDM
#
#       date_of_birth  height  weight  overall_rating  potential_rating  \
# 0        1987-06-24     170      72              93                93
# 1        1985-02-05     187      83              92                92
# 2        1993-01-07     188      87              91                93
# 3        1991-06-28     181      70              91                91
# 4        1992-02-05     175      68              91                91
# ...             ...     ...     ...             ...               ...
# 18997    1999-04-26     177      70              47                52
# 18998    2003-03-30     171      58              47                67
# 18999    1999-02-11     178      66              47                55
# 19000    2003-06-22     175      65              47                67
# 19001    2001-01-29     174      68              47                63
#
#       best_position  best_overall_rating      value    wage  team_id  \
# 0                RW                   93  103500000  560000      5.0
# 1                ST                   92   63000000  220000      6.0
# 2                GK                   91  120000000  125000      8.0
# 3               CAM                   91  129000000  370000      2.0
# 4                LW                   91  132000000  270000      7.0
# ...             ...                  ...        ...     ...      ...
# 18997            CB                   49      70000    1000    595.0
# 18998           CAM                   51     130000     500    646.0
# 18999            CB                   49     100000    1000    409.0
# 19000           CAM                   51     130000     500    646.0
# 19001           CDM                   48     120000     500    400.0
#
#       nationality  crossing  finishing  heading_accuracy  short_passing  \
# 0       Argentina        85         95                70             91
# 1        Portugal        84         95                90             82
# 2        Slovenia        13         11                15             43
# 3         Belgium        94         82                55             94
# 4          Brazil        85         87                62             87
# ...           ...       ...        ...               ...            ...
# 18997    China PR        23         16                45             31
# 18998     England        27         47                36             45
# 18999    China PR        23         26                43             26
# 19000     England        38         42                40             56
# 19001     Bolivia        32         27                48             52
#
#        volleys  defensive_awareness  standing_tackle  sliding_tackle  diving  \
# 0           88                   32               35              24       6
# 1           86                   28               32              24       7
# 2           13                   27               12              18      87
# 3           82                   68               65              53      15
# 4           87                   35               30              29       9
# ...        ...                  ...              ...             ...     ...
# 18997       26                   45               56              47      12
# 18998       47                   18               11              13      11
# 18999       27                   45               52              50       7
# 19000       35                   32               44              40      12
# 19001       32                   43               41              45      10
#
#        handling  kicking  gk_positioning  reflexes  aggression  interceptions  \
# 0            11       15              14         8          44             40
# 1            11       15              14        11          63             29
# 2            92       78              90        90          34             19
# 3            13        5              10        13          76             66
# 4             9       15              15        11          51             36
# ...         ...      ...             ...       ...         ...            ...
# 18997        13        8              14         6          44             50
# 18998        13        9               9         6          33             11
# 18999         8        5              14        11          48             50
# 19000        10        9               6         8          40             23
# 19001         8       15               9        14          57             45
#
#        positioning  vision  penalties  composure  acceleration  sprspeed  \
# 0               93      95         75         96            91        80
# 1               95      82         84         95            87        91
# 2               11      65         11         68            43        60
# 3               88      94         84         91            77        76
# 4               87      90         92         93            94        89
# ...            ...     ...        ...        ...           ...       ...
# 18997           25      25         35         40            60        56
# 18998           43      49         50         45            69        70
# 18999           28      28         38         44            68        60
# 19000           47      47         36         38            63        64
# 19001           30      39         35         36            55        59
#
#        agility  reactions  balance  shot_power  jumping  stamina  strength  \
# 0           91         94       95          86       68       72        69
# 1           87         95       71          94       95       84        78
# 2           67         88       49          59       78       41        78
# 3           78         91       76          91       63       89        74
# 4           96         91       83          80       62       81        50
# ...        ...        ...      ...         ...      ...      ...       ...
# 18997       45         48       70          35       65       55        45
# 18998       67         53       80          50       50       55        35
# 18999       69         46       51          36       57       54        50
# 19000       61         51       66          48       58       43        47
# 19001       59         50       75          41       55       47        47
#
#        long_shots preferred_foot  weak_foot  skill_moves  \
# 0              94           Left          4            4
# 1              93          Right          4            5
# 2              12          Right          3            1
# 3              91          Right          5            4
# 4              84          Right          5            5
# ...           ...            ...        ...          ...
# 18997          23          Right          2            2
# 18998          41          Right          2            2
# 18999          24          Right          2            2
# 19000          30          Right          2            2
# 19001          33          Right          3            2
#
#        international_reputations       work_rate         body_type  dribbling  \
# 0                              5     Medium/ Low            Unique         96
# 1                              5       High/ Low            Unique         88
# 2                              3  Medium/ Medium            Unique         12
# 3                              4      High/ High            Unique         88
# 4                              5    High/ Medium            Unique         95
# ...                          ...             ...               ...        ...
# 18997                          1        Low/ Low  Normal (170-185)         19
# 18998                          1  Medium/ Medium    Lean (170-185)         53
# 18999                          1  Medium/ Medium    Lean (170-185)         27
# 19000                          1  Medium/ Medium    Lean (170-185)         46
# 19001                          1  Medium/ Medium  Normal (170-185)         45
#
#        curve  fk_accuracy  long_passing  ball_control  \
# 0         93           94            91            96
# 1         81           76            77            92
# 2         13           14            40            30
# 3         85           83            93            92
# 4         88           89            81            95
# ...      ...          ...           ...           ...
# 18997     21           22            25            24
# 18998     43           31            37            44
# 18999     23           21            29            42
# 19000     40           35            50            48
# 19001     31           32            47            43
#
#                                        player_speciality  \
# 0      ['Dribbler', 'Distance Shooter', 'FK Specialis...
# 1      ['Aerial Threat', 'Dribbler', 'Distance Shoote...
# 2                                                    NaN
# 3      ['Dribbler', 'Playmaker\xa0', 'Engine', 'Dista...
# 4      ['Speedster', 'Dribbler', 'Playmaker\xa0', 'FK...
# ...                                                  ...
# 18997                                                NaN
# 18998                                                NaN
# 18999                                                NaN
# 19000                                                NaN
# 19001                                                NaN
#
#                                                    trait
# 0      ['Finesse Shot', 'Long Shot Taker (AI)', 'Spee...
# 1      ['Power Free-Kick', 'Flair', 'Long Shot Taker ...
# 2                 ['GK Long Throw', 'Comes For Crosses']
# 3      ['Injury Prone', 'Leadership', 'Early Crosser'...
# 4      ['Injury Prone', 'Flair', 'Speed Dribbler (AI)...
# ...                                                  ...
# 18997                                                NaN
# 18998                                                NaN
# 18999                                                NaN
# 19000                                                NaN
# 19001                                                NaN
#
# [19002 rows x 56 columns]
