# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 30)

# %%
df_orig = pd.read_csv('../Data/players.csv')

# %%
df_orig.head()
# Out:
#    player_id                          player_name   positions date_of_birth  \
# 0          1       Lionel Andrés Messi Cuccittini  RW, ST, CF    1987-06-24
# 1          2  Cristiano Ronaldo dos Santos Aveiro      ST, LW    1985-02-05
# 2          3                            Jan Oblak          GK    1993-01-07
# 3          4                      Kevin De Bruyne     CAM, CM    1991-06-28
# 4          5        Neymar da Silva Santos Júnior     LW, CAM    1992-02-05
#
#    height  weight  overall_rating  potential_rating best_position  \
# 0     170      72              93                93            RW
# 1     187      83              92                92            ST
# 2     188      87              91                93            GK
# 3     181      70              91                91           CAM
# 4     175      68              91                91            LW
#
#    best_overall_rating      value    wage  team_id nationality  crossing  \
# 0                   93  103500000  560000      5.0   Argentina        85
# 1                   92   63000000  220000      6.0    Portugal        84
# 2                   91  120000000  125000      8.0    Slovenia        13
# 3                   91  129000000  370000      2.0     Belgium        94
# 4                   91  132000000  270000      7.0      Brazil        85
#
#    finishing  heading_accuracy  short_passing  volleys  defensive_awareness  \
# 0         95                70             91       88                   32
# 1         95                90             82       86                   28
# 2         11                15             43       13                   27
# 3         82                55             94       82                   68
# 4         87                62             87       87                   35
#
#    standing_tackle  sliding_tackle  diving  handling  kicking  gk_positioning  \
# 0               35              24       6        11       15              14
# 1               32              24       7        11       15              14
# 2               12              18      87        92       78              90
# 3               65              53      15        13        5              10
# 4               30              29       9         9       15              15
#
#    reflexes  aggression  interceptions  positioning  vision  penalties  \
# 0         8          44             40           93      95         75
# 1        11          63             29           95      82         84
# 2        90          34             19           11      65         11
# 3        13          76             66           88      94         84
# 4        11          51             36           87      90         92
#
#    composure  acceleration  sprspeed  agility  reactions  balance  shot_power  \
# 0         96            91        80       91         94       95          86
# 1         95            87        91       87         95       71          94
# 2         68            43        60       67         88       49          59
# 3         91            77        76       78         91       76          91
# 4         93            94        89       96         91       83          80
#
#    jumping  stamina  strength  long_shots preferred_foot  weak_foot  \
# 0       68       72        69          94           Left          4
# 1       95       84        78          93          Right          4
# 2       78       41        78          12          Right          3
# 3       63       89        74          91          Right          5
# 4       62       81        50          84          Right          5
#
#    skill_moves  international_reputations       work_rate body_type  \
# 0            4                          5     Medium/ Low    Unique
# 1            5                          5       High/ Low    Unique
# 2            1                          3  Medium/ Medium    Unique
# 3            4                          4      High/ High    Unique
# 4            5                          5    High/ Medium    Unique
#
#    dribbling  curve  fk_accuracy  long_passing  ball_control  \
# 0         96     93           94            91            96
# 1         88     81           76            77            92
# 2         12     13           14            40            30
# 3         88     85           83            93            92
# 4         95     88           89            81            95
#
#                                    player_speciality  \
# 0  ['Dribbler', 'Distance Shooter', 'FK Specialis...
# 1  ['Aerial Threat', 'Dribbler', 'Distance Shoote...
# 2                                                NaN
# 3  ['Dribbler', 'Playmaker\xa0', 'Engine', 'Dista...
# 4  ['Speedster', 'Dribbler', 'Playmaker\xa0', 'FK...
#
#                                                trait
# 0  ['Finesse Shot', 'Long Shot Taker (AI)', 'Spee...
# 1  ['Power Free-Kick', 'Flair', 'Long Shot Taker ...
# 2             ['GK Long Throw', 'Comes For Crosses']
# 3  ['Injury Prone', 'Leadership', 'Early Crosser'...
# 4  ['Injury Prone', 'Flair', 'Speed Dribbler (AI)...

# %%
df_orig.columns
# Out:
# Index(['player_id', 'player_name', 'positions', 'date_of_birth', 'height',
#        'weight', 'overall_rating', 'potential_rating', 'best_position',
#        'best_overall_rating', 'value', 'wage', 'team_id', 'nationality',
#        'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'defensive_awareness', 'standing_tackle', 'sliding_tackle', 'diving',
#        'handling', 'kicking', 'gk_positioning', 'reflexes', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'composure',
#        'acceleration', 'sprspeed', 'agility', 'reactions', 'balance',
#        'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputations', 'work_rate', 'body_type', 'dribbling',
#        'curve', 'fk_accuracy', 'long_passing', 'ball_control',
#        'player_speciality', 'trait'],
#       dtype='object')

# %%
df_orig.columns=[i.replace('int_','').replace('str_','').replace('dt_','') for i in df_orig.columns]

# %%
profile = ProfileReport(df_orig,title='Fifa 21 Dataset',explorative=False)
# profile.to_file('report.html')
# profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/69 [00:00<?, ?it/s]
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-684e059a4b8e>", line 2, in <module>
#     profile.to_file('report.html')
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 261, in to_file
#     data = self.to_html()
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 372, in to_html
#     return self.html
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 189, in html
#     self._html = self._render_html()
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 291, in _render_html
#     report = self.report
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 183, in report
#     self._report = get_report_structure(self.config, self.description_set)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 170, in description_set
#     self._sample,
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/describe.py", line 100, in describe
#     config, df, correlation_name, series_description
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/correlations.py", line 185, in calculate_correlation
#     config, df, summary
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/correlations.py", line 43, in compute
#     return df.corr(method="kendall")
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py", line 9378, in corr
#     correl = libalgos.nancorr_kendall(mat, minp=min_periods)
#   File "pandas/_libs/algos.pyx", line 541, in pandas._libs.algos.nancorr_kendall
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/inspect.py", line 734, in getmodule
#     f = module.__file__
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-684e059a4b8e>", line 2, in <module>
#     profile.to_file('report.html')
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 261, in to_file
#     data = self.to_html()
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 372, in to_html
#     return self.html
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 189, in html
#     self._html = self._render_html()
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 291, in _render_html
#     report = self.report
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 183, in report
#     self._report = get_report_structure(self.config, self.description_set)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py", line 170, in description_set
#     self._sample,
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/describe.py", line 100, in describe
#     config, df, correlation_name, series_description
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/correlations.py", line 185, in calculate_correlation
#     config, df, summary
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/correlations.py", line 43, in compute
#     return df.corr(method="kendall")
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py", line 9378, in corr
#     correl = libalgos.nancorr_kendall(mat, minp=min_periods)
#   File "pandas/_libs/algos.pyx", line 541, in pandas._libs.algos.nancorr_kendall
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3434, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/inspect.py", line 1464, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py", line 170, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/eashwar/opt/anaconda3/envs/ml_env/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-17-684e059a4b8e> in <module>
#       1 profile = ProfileReport(df_orig,title='Fifa 21 Dataset',explorative=False)
# ----> 2 profile.to_file('report.html')
#       3 # profile.to_notebook_iframe()
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py in to_file(self, output_file, silent)
#     260
# --> 261             data = self.to_html()
#     262
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     371         """
# --> 372         return self.html
#     373
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py in html(self)
#     188         if self._html is None:
# --> 189             self._html = self._render_html()
#     190         return self._html
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py in _render_html(self)
#     290
# --> 291         report = self.report
#     292
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py in report(self)
#     182         if self._report is None:
# --> 183             self._report = get_report_structure(self.config, self.description_set)
#     184         return self._report
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/profile_report.py in description_set(self)
#     169                 self.typeset,
# --> 170                 self._sample,
#     171             )
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/describe.py in describe(config, df, summarizer, typeset, sample)
#      99             correlations[correlation_name] = calculate_correlation(
# --> 100                 config, df, correlation_name, series_description
#     101             )
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/correlations.py in calculate_correlation(config, df, correlation_name, summary)
#     184         correlation = correlation_measures[correlation_name].compute(
# --> 185             config, df, summary
#     186         )
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas_profiling/model/correlations.py in compute(config, df, summary)
#      42     ) -> Optional[pd.DataFrame]:
# ---> 43         return df.corr(method="kendall")
#      44
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in corr(self, method, min_periods)
#    9377         elif method == "kendall":
# -> 9378             correl = libalgos.nancorr_kendall(mat, minp=min_periods)
#    9379         elif callable(method):
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/_libs/algos.pyx in pandas._libs.algos.nancorr_kendall()
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45
# ---> 46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3336                         asy = compare(code)
# -> 3337                     if (await self.run_code(code, result,  async_=asy)):
#    3338                         return True
#
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3144
#    3145                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# -> 3146                        interactivity=interactivity, compiler=compiler, result=result)
#    3147
#    3148                 self.last_execution_succeeded = not has_raised
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3354             if result:
#    3355                 result.error_before_exec = sys.exc_info()[1]
# -> 3356             self.showtraceback()
#    3357             return True
#    3358
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1209         while evalue:
#    1210             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
# -> 1211                                                                      chained_exceptions_tb_offset)
#    1212             exception = self.get_parts_of_chained_exception(evalue)
#    1213
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_orig['work_rate']=df_orig['work_rate'].apply(lambda x : x.replace(' ',''))
df_orig['positions']=df_orig['positions'].apply(lambda x : x.replace(' ','').split(','))

df=df_orig.copy()
df=df[['height',
       'weight', 'overall_rating', 
       'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
       'defensive_awareness', 'standing_tackle', 'sliding_tackle', 'diving',
       'handling', 'kicking', 'gk_positioning', 'reflexes', 'aggression',
       'interceptions', 'positioning', 'vision', 'penalties', 'composure',
       'acceleration', 'sprspeed', 'agility', 'reactions', 'balance',
       'shot_power', 'jumping', 'stamina', 'strength','long_shots',
       'work_rate', 'dribbling',
       'curve', 'fk_accuracy', 'long_passing', 'ball_control',
       'positions']]
df.columns

# %%
df.info()

# %%
df.head()

# %% [markdown]
# > **EDA**

# %% [markdown]
# ### Multilabel Classification

# %%
# Pipeline
from sklearn.pipeline import Pipeline

# preprocessor
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# estimator
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df.head()

# %%
# Numerical Features
num_col = numerical_features.copy()

num_steps = [
             ('impute',SimpleImputer(strategy='mean')),
             ('scaler', StandardScaler()),
            ]

num_pipeline = Pipeline(num_steps)

# %%
# Categorical features
cat_col = ['work_rate','']

cat_steps = [
             ('impute',SimpleImputer(strategy='constant')),
             ('encoder',OneHotEncoder())
            ]
cat_pipeline = Pipeline(cat_steps)

# %%
class CustomTarget(BaseEstimator, TransformerMixin):
    def __init__(self):
        super().__init__()
        self.age_means_ = {}

    def fit(self, X, y=None):
        self.age_means_ = X.groupby(['Pclass', 'Sex']).Age.mean()

        return self

    def transform(self, X, y=None):
        # fill Age
        for key, value in self.age_means_.items():
            X.loc[((np.isnan(X["Age"])) & (X.Pclass == key[0]) & (X.Sex == key[1])), 'Age'] = value

        return X

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
X=df[numerical_features].copy()
temp=df['work_rate'].copy()
t=pd.get_dummies(temp,drop_first=True)
X=X.join(t)

y_orig=df['best_position'].copy()
mapping = {i:j for i,j in zip(y_orig.unique(),range(y_orig.nunique()))}
reverse_mapping={value:key for key, value in mapping.items()}
y=y_orig.map(mapping).copy()
y=np.array(y).reshape(-1,1)
# y=pd.get_dummies(y_orig,drop_first=True)

# %%
y

# %%
X.shape,y.shape

# %%
X.head()

# %%
numerical_features

# %%
dtc = DecisionTreeClassifier(max_depth = 2).fit(X, y)

dtc.fit(X,y)

# %%
y_pred = dtc.predict(X)

# %%
cm = confusion_matrix(y, y_pred)

# %%
y_pred

# %%
cm

# %%
y_pred_name = pd.Series(y_pred).map(reverse_mapping)

# %%
y_orig,y_pred_name

# %%
df_orig = pd.read_csv('../Data/players.csv')
df_orig.columns=[i.replace('int_','').replace('str_','').replace('dt_','') for i in df_orig.columns]

temp = df_orig[['height','weight', 'overall_rating', 
       'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
       'defensive_awareness', 'standing_tackle', 'sliding_tackle', 'diving',
       'handling', 'kicking', 'gk_positioning', 'reflexes', 'aggression',
       'interceptions', 'positioning', 'vision', 'penalties', 'composure',
       'acceleration', 'sprspeed', 'agility', 'reactions', 'balance',
       'shot_power', 'jumping', 'stamina', 'strength','long_shots',
       'work_rate', 'dribbling',
       'curve', 'fk_accuracy', 'long_passing', 'ball_control',
       'positions']].copy()
temp['positions'] = temp['positions'].apply(lambda x: x.replace(' ',''))
temp['positions'] = temp['positions'].apply(lambda x: x.split(','))
temp['work_rate'] = temp['work_rate'].apply(lambda x: x.replace(' ',''))

all_positions = list(df_orig['best_position'].unique())

# %%
temp

# %%
all_positions,len(all_positions)

# %%
temp['work_rate'].unique()

# %%
for i in all_positions:
    temp[i]=temp['positions'].apply(lambda x: int(i in x))

# %%
temp1=temp[[i for i in temp.columns if i not in ['positions','work_rate']]].copy()

# %%
X=temp1[['height', 'weight', 'overall_rating', 'crossing', 'finishing',
       'heading_accuracy', 'short_passing', 'volleys', 'defensive_awareness',
       'standing_tackle', 'sliding_tackle', 'diving', 'handling', 'kicking',
       'gk_positioning', 'reflexes', 'aggression', 'interceptions',
       'positioning', 'vision', 'penalties', 'composure', 'acceleration',
       'sprspeed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping',
       'stamina', 'strength', 'long_shots',  'dribbling', 'curve',
       'fk_accuracy', 'long_passing', 'ball_control' ]].copy()
y=temp1[['RW', 'ST', 'GK', 'CAM',
       'LW', 'CB', 'CDM', 'CF', 'LM', 'CM', 'RB', 'LB', 'RM', 'LWB', 'RWB']].copy()

# %%
from skmultilearn.problem_transform import ClassifierChain
from sklearn.linear_model import LogisticRegression

# %%
inp=np.array(X.iloc[0,:])
inp

# %%
classifier = ClassifierChain(LogisticRegression(C=1))
classifier.fit(X, y)
predictions = classifier.predict(X)

# %%
np.array(predictions.todense())

# %%
np.array(y)

# %%
np.array(y.iloc[0,:])

# %%
import pandas_profiling

# %%
df_orig
# Out:
#        player_id                          player_name   positions  \
# 0              1       Lionel Andrés Messi Cuccittini  RW, ST, CF
# 1              2  Cristiano Ronaldo dos Santos Aveiro      ST, LW
# 2              3                            Jan Oblak          GK
# 3              4                      Kevin De Bruyne     CAM, CM
# 4              5        Neymar da Silva Santos Júnior     LW, CAM
# ...          ...                                  ...         ...
# 18997      18998                                  张梦炫          CB
# 18998      18999                        Vani Da Silva          ST
# 18999      19000                                   夏奥          CB
# 19000      19001                            Ben Hough          CM
# 19001      19002          Mateo Nicolás Flores Cuevas         CDM
#
#       date_of_birth  height  weight  overall_rating  potential_rating  \
# 0        1987-06-24     170      72              93                93
# 1        1985-02-05     187      83              92                92
# 2        1993-01-07     188      87              91                93
# 3        1991-06-28     181      70              91                91
# 4        1992-02-05     175      68              91                91
# ...             ...     ...     ...             ...               ...
# 18997    1999-04-26     177      70              47                52
# 18998    2003-03-30     171      58              47                67
# 18999    1999-02-11     178      66              47                55
# 19000    2003-06-22     175      65              47                67
# 19001    2001-01-29     174      68              47                63
#
#       best_position  best_overall_rating      value    wage  team_id  \
# 0                RW                   93  103500000  560000      5.0
# 1                ST                   92   63000000  220000      6.0
# 2                GK                   91  120000000  125000      8.0
# 3               CAM                   91  129000000  370000      2.0
# 4                LW                   91  132000000  270000      7.0
# ...             ...                  ...        ...     ...      ...
# 18997            CB                   49      70000    1000    595.0
# 18998           CAM                   51     130000     500    646.0
# 18999            CB                   49     100000    1000    409.0
# 19000           CAM                   51     130000     500    646.0
# 19001           CDM                   48     120000     500    400.0
#
#       nationality  crossing  finishing  heading_accuracy  short_passing  \
# 0       Argentina        85         95                70             91
# 1        Portugal        84         95                90             82
# 2        Slovenia        13         11                15             43
# 3         Belgium        94         82                55             94
# 4          Brazil        85         87                62             87
# ...           ...       ...        ...               ...            ...
# 18997    China PR        23         16                45             31
# 18998     England        27         47                36             45
# 18999    China PR        23         26                43             26
# 19000     England        38         42                40             56
# 19001     Bolivia        32         27                48             52
#
#        volleys  defensive_awareness  standing_tackle  sliding_tackle  diving  \
# 0           88                   32               35              24       6
# 1           86                   28               32              24       7
# 2           13                   27               12              18      87
# 3           82                   68               65              53      15
# 4           87                   35               30              29       9
# ...        ...                  ...              ...             ...     ...
# 18997       26                   45               56              47      12
# 18998       47                   18               11              13      11
# 18999       27                   45               52              50       7
# 19000       35                   32               44              40      12
# 19001       32                   43               41              45      10
#
#        handling  kicking  gk_positioning  reflexes  aggression  interceptions  \
# 0            11       15              14         8          44             40
# 1            11       15              14        11          63             29
# 2            92       78              90        90          34             19
# 3            13        5              10        13          76             66
# 4             9       15              15        11          51             36
# ...         ...      ...             ...       ...         ...            ...
# 18997        13        8              14         6          44             50
# 18998        13        9               9         6          33             11
# 18999         8        5              14        11          48             50
# 19000        10        9               6         8          40             23
# 19001         8       15               9        14          57             45
#
#        positioning  vision  penalties  composure  acceleration  sprspeed  \
# 0               93      95         75         96            91        80
# 1               95      82         84         95            87        91
# 2               11      65         11         68            43        60
# 3               88      94         84         91            77        76
# 4               87      90         92         93            94        89
# ...            ...     ...        ...        ...           ...       ...
# 18997           25      25         35         40            60        56
# 18998           43      49         50         45            69        70
# 18999           28      28         38         44            68        60
# 19000           47      47         36         38            63        64
# 19001           30      39         35         36            55        59
#
#        agility  reactions  balance  shot_power  jumping  stamina  strength  \
# 0           91         94       95          86       68       72        69
# 1           87         95       71          94       95       84        78
# 2           67         88       49          59       78       41        78
# 3           78         91       76          91       63       89        74
# 4           96         91       83          80       62       81        50
# ...        ...        ...      ...         ...      ...      ...       ...
# 18997       45         48       70          35       65       55        45
# 18998       67         53       80          50       50       55        35
# 18999       69         46       51          36       57       54        50
# 19000       61         51       66          48       58       43        47
# 19001       59         50       75          41       55       47        47
#
#        long_shots preferred_foot  weak_foot  skill_moves  \
# 0              94           Left          4            4
# 1              93          Right          4            5
# 2              12          Right          3            1
# 3              91          Right          5            4
# 4              84          Right          5            5
# ...           ...            ...        ...          ...
# 18997          23          Right          2            2
# 18998          41          Right          2            2
# 18999          24          Right          2            2
# 19000          30          Right          2            2
# 19001          33          Right          3            2
#
#        international_reputations       work_rate         body_type  dribbling  \
# 0                              5     Medium/ Low            Unique         96
# 1                              5       High/ Low            Unique         88
# 2                              3  Medium/ Medium            Unique         12
# 3                              4      High/ High            Unique         88
# 4                              5    High/ Medium            Unique         95
# ...                          ...             ...               ...        ...
# 18997                          1        Low/ Low  Normal (170-185)         19
# 18998                          1  Medium/ Medium    Lean (170-185)         53
# 18999                          1  Medium/ Medium    Lean (170-185)         27
# 19000                          1  Medium/ Medium    Lean (170-185)         46
# 19001                          1  Medium/ Medium  Normal (170-185)         45
#
#        curve  fk_accuracy  long_passing  ball_control  \
# 0         93           94            91            96
# 1         81           76            77            92
# 2         13           14            40            30
# 3         85           83            93            92
# 4         88           89            81            95
# ...      ...          ...           ...           ...
# 18997     21           22            25            24
# 18998     43           31            37            44
# 18999     23           21            29            42
# 19000     40           35            50            48
# 19001     31           32            47            43
#
#                                        player_speciality  \
# 0      ['Dribbler', 'Distance Shooter', 'FK Specialis...
# 1      ['Aerial Threat', 'Dribbler', 'Distance Shoote...
# 2                                                    NaN
# 3      ['Dribbler', 'Playmaker\xa0', 'Engine', 'Dista...
# 4      ['Speedster', 'Dribbler', 'Playmaker\xa0', 'FK...
# ...                                                  ...
# 18997                                                NaN
# 18998                                                NaN
# 18999                                                NaN
# 19000                                                NaN
# 19001                                                NaN
#
#                                                    trait
# 0      ['Finesse Shot', 'Long Shot Taker (AI)', 'Spee...
# 1      ['Power Free-Kick', 'Flair', 'Long Shot Taker ...
# 2                 ['GK Long Throw', 'Comes For Crosses']
# 3      ['Injury Prone', 'Leadership', 'Early Crosser'...
# 4      ['Injury Prone', 'Flair', 'Speed Dribbler (AI)...
# ...                                                  ...
# 18997                                                NaN
# 18998                                                NaN
# 18999                                                NaN
# 19000                                                NaN
# 19001                                                NaN
#
# [19002 rows x 56 columns]
